# %% [markdown]
# ### Data analysis of Rio de Janeiro olympics 2016
# In this project, I will analyze the data of the Rio de Janeiro Olympics using seaborn , matplotlib and plotly

# %%
import pandas as pd # for reading data
import seaborn as sns # for plotting
import plotly.express as px # for plotting
import matplotlib.pyplot as plt # for plotting

# %% [markdown]
# First I will read the data using pands

# %%
df_olympic = pd.read_csv('../input/120-years-of-olympic-history-athletes-and-results/athlete_events.csv')

# %% [markdown]
# Then I will filter the data to include 2016 only and some sports اhall

# %%
sports_hall = ['Volleyball' , 'Basketball']
basket_volley = df_olympic[(df_olympic['Year'] == 2016) & df_olympic['Sport'].isin(sports_hall)]

# %% [markdown]
# It is important that the athlete's body is perfect, that is, there is consistency between height and weight
#
# I want to see the relationship between the heights and weights of players in team sports
#
# So , I will use relplot (like to scatter plot) from seaborn to display the weights and heights of players in team ball sports

# %% [markdown]
# The following figure shows that there is a strong correlation between height and weight in these sports (there is a good consistency between height and weight)

# %%
sns.relplot(x="Height", y="Weight", hue="Sport" , data=basket_volley , s = 80)

# %% [markdown]
# There is too much data in the previous graph, which led to data accumulation in this graph
#
# I will use an alternative to scatter plot to solve this problem so that if there is a lot of data in a certain range it is represented by a darker color and if there is less data in a certain range it is represented by a lighter color
# The alternative is hexbin plot from seaborn which use hexagons to represent clusters of data points
#
# 1- The darker bins indicate larger number of points on x and y
#
# 2- The lighter bins indicate fewer points
#
# the histogram on the top and right axes depict the variance in the features

# %%
sns.jointplot(basket_volley.Height, basket_volley.Weight, kind="hex", color="#4CB391" )
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# I want to use the box plot to see some statistical characteristics (such as the maximum value, minimum value and average) of the heights of the players of the participating teams in basketball
#
# So , I filter my data to include only basketball

# %%
basketball = basket_volley.query("Sport == 'Basketball'")
basketball.head()
# Out:
#         ID                              Name Sex   Age  Height  Weight  \
# 1029   576   Alejandro "lex" Abrines Redondo   M  23.0   198.0    93.0
# 1215   683            Natalie Chioma Achonwa   F  23.0   190.0    86.0
# 1322   742                      Roberto Acua   M  25.0   208.0   109.0
# 1867  1023  Adriana "Adrianinha" Moiss Pinto   F  37.0   170.0    65.0
# 3049  1701    Joshua Emmanuel "Josh" Akognon   M  30.0   189.0    83.0
#
#            Team  NOC        Games  Year  Season            City       Sport  \
# 1029      Spain  ESP  2016 Summer  2016  Summer  Rio de Janeiro  Basketball
# 1215     Canada  CAN  2016 Summer  2016  Summer  Rio de Janeiro  Basketball
# 1322  Argentina  ARG  2016 Summer  2016  Summer  Rio de Janeiro  Basketball
# 1867     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro  Basketball
# 3049    Nigeria  NGR  2016 Summer  2016  Summer  Rio de Janeiro  Basketball
#
#                               Event   Medal
# 1029    Basketball Men's Basketball  Bronze
# 1215  Basketball Women's Basketball     NaN
# 1322    Basketball Men's Basketball     NaN
# 1867  Basketball Women's Basketball     NaN
# 3049    Basketball Men's Basketball     NaN

# %% [markdown]
# ### Can we determine the positions of the players based on the height using this boxplot ?
#
# Yes, we can.
#
# You can see in this plot that the shortest player is the Japanese national team player about 163 centimeters
# The position of this player is the team's Point Guard (or playmaker) because he is the shortest player
#
# Also, the tallest player is the Chinese national team player, about 218 centimeters
# The position of this player is mostly center player

# %%
ax = sns.boxplot(x='Team', y='Height', data=basketball)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Spain'),
#  Text(1, 0, 'Canada'),
#  Text(2, 0, 'Argentina'),
#  Text(3, 0, 'Brazil'),
#  Text(4, 0, 'Nigeria'),
#  Text(5, 0, 'Turkey'),
#  Text(6, 0, 'France'),
#  Text(7, 0, 'Australia'),
#  Text(8, 0, 'United States'),
#  Text(9, 0, 'Croatia'),
#  Text(10, 0, 'Serbia'),
#  Text(11, 0, 'China'),
#  Text(12, 0, 'Venezuela'),
#  Text(13, 0, 'Senegal'),
#  Text(14, 0, 'Lithuania'),
#  Text(15, 0, 'Belarus'),
#  Text(16, 0, 'Japan')]

# %% [markdown]
# I want to do the same thing with volleyball

# %%
volleyball = basket_volley.query("Sport == 'Volleyball'")
volleyball.head()
# Out:
#       ID                 Name Sex   Age  Height  Weight      Team  NOC  \
# 299  161       Hossam Abdalla   M  28.0   203.0    97.0     Egypt  EGY
# 366  203    Ahmed Abdel Naeim   M  31.0   197.0    87.0     Egypt  EGY
# 410  227       Ahmed Abdelaal   M  27.0   188.0    89.0     Egypt  EGY
# 443  246   Mamdouh Abdelrehim   M  26.0   207.0    90.0     Egypt  EGY
# 489  269  Fawziya Abdoulkarim   F  27.0   180.0    67.0  Cameroon  CMR
#
#            Games  Year  Season            City       Sport  \
# 299  2016 Summer  2016  Summer  Rio de Janeiro  Volleyball
# 366  2016 Summer  2016  Summer  Rio de Janeiro  Volleyball
# 410  2016 Summer  2016  Summer  Rio de Janeiro  Volleyball
# 443  2016 Summer  2016  Summer  Rio de Janeiro  Volleyball
# 489  2016 Summer  2016  Summer  Rio de Janeiro  Volleyball
#
#                              Event Medal
# 299    Volleyball Men's Volleyball   NaN
# 366    Volleyball Men's Volleyball   NaN
# 410    Volleyball Men's Volleyball   NaN
# 443    Volleyball Men's Volleyball   NaN
# 489  Volleyball Women's Volleyball   NaN

# %% [markdown]
# We will determine the positions of some players in volleyball sport using the boxplot , as we did in basketball sport
#
# The height of one of the Argentine players is about 164 centimeters, and he is the shortest player in the national team. This player's position is libero(Middle Back) , usually wearing an opposite colored jersey
#
# the tallest player is the Egyptian national team player, about 212 centimeters
# The position of this player is middle blocker(sometimes known as the middle hitter) The main role for this player is being the first line of defense against the opposing team’s hits

# %%
ax = sns.boxplot(x='Team', y='Height', data=volleyball)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Egypt'),
#  Text(1, 0, 'Cameroon'),
#  Text(2, 0, 'Argentina'),
#  Text(3, 0, 'United States'),
#  Text(4, 0, 'Brazil'),
#  Text(5, 0, 'Mexico'),
#  Text(6, 0, 'Italy'),
#  Text(7, 0, 'Japan'),
#  Text(8, 0, 'Russia'),
#  Text(9, 0, 'South Korea'),
#  Text(10, 0, 'Netherlands'),
#  Text(11, 0, 'Canada'),
#  Text(12, 0, 'Poland'),
#  Text(13, 0, 'Serbia'),
#  Text(14, 0, 'Cuba'),
#  Text(15, 0, 'Puerto Rico'),
#  Text(16, 0, 'China'),
#  Text(17, 0, 'Iran'),
#  Text(18, 0, 'France')]

# %% [markdown]
# Now I will filter the data on the teams that only got medals in the 2016 Olympics

# %%
Medals = ['Gold', 'Bronze', 'Silver']
winners = df_olympic[(df_olympic['Year'] == 2016) & df_olympic['Medal'].isin(Medals)]
winners.head()
# Out:
#       ID                         Name Sex   Age  Height  Weight        Team  \
# 158   62            Giovanni Abagnale   M  21.0   198.0    90.0       Italy
# 161   65            Patimat Abakarova   F  21.0   165.0    49.0  Azerbaijan
# 175   73                    Luc Abalo   M  31.0   182.0    86.0      France
# 450  250         Saeid Morad Abdevali   M  26.0   170.0    80.0        Iran
# 794  455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0      Russia
#
#      NOC        Games  Year  Season            City       Sport  \
# 158  ITA  2016 Summer  2016  Summer  Rio de Janeiro      Rowing
# 161  AZE  2016 Summer  2016  Summer  Rio de Janeiro   Taekwondo
# 175  FRA  2016 Summer  2016  Summer  Rio de Janeiro    Handball
# 450  IRI  2016 Summer  2016  Summer  Rio de Janeiro   Wrestling
# 794  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                          Event   Medal
# 158                 Rowing Men's Coxless Pairs  Bronze
# 161                Taekwondo Women's Flyweight  Bronze
# 175                    Handball Men's Handball  Silver
# 450  Wrestling Men's Middleweight, Greco-Roman  Bronze
# 794           Gymnastics Men's Team All-Around  Silver

# %% [markdown]
# ### Analyze by describing data

# %%
winners.describe()
# Out:
#                   ID          Age       Height       Weight    Year
# count    2023.000000  2023.000000  2020.000000  2015.000000  2023.0
# mean    69636.668809    26.325260   178.370792    73.961787  2016.0
# std     39467.602820     5.149783    11.872888    16.216173     0.0
# min        62.000000    15.000000   140.000000    33.000000  2016.0
# 25%     34747.000000    23.000000   170.000000    63.000000  2016.0
# 50%     71060.000000    26.000000   178.000000    72.000000  2016.0
# 75%    103656.000000    29.000000   186.000000    83.500000  2016.0
# max    135525.000000    58.000000   215.000000   160.000000  2016.0

# %% [markdown]
# 1- Average age of players is 26.32
#
# 2- Age of oldest player is 58 years
#
# 3- Age of the youngest player is 15 years
#
# 4- Average height of players around 178.37
#
# 5- tallest player around 215 cm
#
# 6- shortest player around 140 cm
#
# 7- Average weight of players around 73.96kg

# %%
winners.describe(include=object)
# Out:
#                            Name   Sex           Team   NOC        Games  \
# count                      2023  2023           2023  2023         2023
# unique                     1855     2             98    86            1
# top     Michael Fred Phelps, II     M  United States   USA  2016 Summer
# freq                          6  1054            256   264         2023
#
#         Season            City      Sport                      Event   Medal
# count     2023            2023       2023                       2023    2023
# unique       1               1         34                        306       3
# top     Summer  Rio de Janeiro  Athletics  Football Women's Football  Bronze
# freq      2023            2023        192                         54     703

# %% [markdown]
# 1- This table shows that the number of teams participating in the Olympics is 98
#
# 2- Number of sports 34
#
# 3- The most frequently mentioned name in the Olympics is Michael Fred Phelps
#
# 4- The most awarded medal in the Olympics is the bronze with 703 medals

# %% [markdown]
# In this code, I used a pie chart to plot a percentage that expresses the proportion of Male and Female who won the Rio Olympics

# %%
mycolors = ["#FF865E", "#FEE440"]
winners['Sex'].value_counts().plot(kind="pie", autopct="%.2f" , shadow = True , colors = mycolors)
# Out:
# <AxesSubplot:ylabel='Sex'>

# %% [markdown]
# Let's calculate the number of different medals (gold - silver - bronze)

# %%
Medals = winners['Medal'].value_counts()

# %% [markdown]
# With the same idea as before, I used a donut chart to represent the percentage of medals (gold - silver - bronze) awarded in all sports

# %%
explode = (0.05, 0.05 , 0.05)
plt.pie(Medals , labels = ['Gold' , 'Bronze' , 'Silver'] , autopct="%.2f" , explode = explode, pctdistance=0.85 )
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
  
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)
  
# Adding Title of chart
plt.legend(title = 'Medals' , bbox_to_anchor =(0.75, 1.15), ncol = 3 , loc = 'lower left')
plt.title('the Percentage of each medal awarded at the Rio Olympics' , loc = 'center')
  
# Displaing Chart
plt.show()

# %% [markdown]
# I will use this code to calculate how many medals each country has won
#
# and From this list I will only take the five countries with the most medals

# %%
winners['Team'].value_counts()
# Out:
# United States          256
# Germany                157
# Great Britain          145
# Russia                 113
# China                  109
#                       ...
# Grenada                  1
# Philippines              1
# Jordan                   1
# Qatar                    1
# Trinidad and Tobago      1
# Name: Team, Length: 98, dtype: int64

# %% [markdown]
# I wanted to know how many gold, silver and bronze medals each of the five countries (which we referred to earlier) had won

# %%
country_winner = winners[winners.Team.isin(["United States", "Germany" , "Great Britain" , "Russia" , "China"])]

# %% [markdown]
# I used this code so that I first filter our data to include these countries and then put them into a group or a special table (to count how many different medals each of the five countries اhad won)

# %%
five_country = country_winner.groupby(['Team'])['Medal'].value_counts().unstack().fillna(0)
five_country
# Out:
# Medal          Bronze  Gold  Silver
# Team
# China              35    44      30
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# United States      67   137      52

# %% [markdown]
# I used the stacked bar to draw the previous table

# %%
stacked_fig = five_country.plot(kind='bar', stacked=True , color=['#17D7A0' , '#FF5403' , '#8E05C2'])

# %% [markdown]
# Let's see the ages of the players of these five countries

# %%
sns.distplot(country_winner.Age, kde=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# I am now going to filter our data table to contain only the five most medal winning countries and then calculate the number of medals awarded in each game from this table

# %%
sports = country_winner['Sport'].value_counts()
sports
# Out:
# Swimming                 94
# Athletics                69
# Rowing                   56
# Gymnastics               50
# Hockey                   49
# Cycling                  37
# Volleyball               36
# Football                 35
# Handball                 30
# Equestrianism            30
# Fencing                  30
# Water Polo               26
# Diving                   25
# Canoeing                 24
# Basketball               24
# Synchronized Swimming    22
# Shooting                 20
# Table Tennis             16
# Boxing                   15
# Wrestling                15
# Rugby Sevens             12
# Sailing                   9
# Judo                      9
# Archery                   8
# Weightlifting             8
# Taekwondo                 7
# Rhythmic Gymnastics       7
# Triathlon                 4
# Trampolining              4
# Badminton                 3
# Golf                      3
# Tennis                    2
# Modern Pentathlon         1
# Name: Sport, dtype: int64

# %% [markdown]
# I'll filter our data table again by the five sports with the most medals
#
# And we are using the Seaborn to plot it

# %%
sport = ['Swimming' , 'Athletics' , 'Rowing' , 'Gymnastics' , 'Hockey']
sports_medals = country_winner[country_winner['Sport'].isin(sport)]
sns.catplot("Sport", data=sports_medals, aspect=1.5, kind="count", color="b")
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# I want to make a comparison between the five countries (most winning medals) in the previous five sports to see who excelled in these sports

# %%
g = sns.FacetGrid(sports_medals, col="Sport", height=4,aspect=.5,hue='NOC',palette='magma_r')
g.map(sns.countplot, "NOC", order = sports_medals['NOC'].value_counts().index)

# %% [markdown]
# I will repeat the previous graph, but this time the comparison will be between Male and Female

# %%
s = sns.FacetGrid(sports_medals, col="Sport", height=4,aspect=.5,hue='Sex',palette='magma_r')
s.map(sns.countplot, "Sex", order = sports_medals['Sex'].value_counts().index)

# %% [markdown]
# In the end
# I just liked that I am drawing a map of the world showing the countries that got the Olympic medals (golden - silver - bronze) You can drag and you can move between the medals through the bar at the bottom of the map

# %%
fig = px.choropleth(winners,
                    locations="NOC",
                    color='Medal',
                    hover_name="Team",
                    animation_frame = "Medal",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4d24de24-2341-452d-84b6-c30daefd1c08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d24de24-2341-452d-84b6-c30daefd1c08")) {                    Plotly.newPlot(                        "4d24de24-2341-452d-84b6-c30daefd1c08",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Medal=Bronze<br>NOC=%{location}<extra></extra>","hovertext":["Italy","Azerbaijan","Iran","Russia","Australia","Spain","United States","United States","United States","South Africa","South Africa","Germany","Italy","Nigeria","Canada","Uzbekistan","United States","Nigeria","United States","Individual Olympic Athletes","Iran","Norway","Cuba","Tunisia","Nigeria","Denmark","United States","Russia","Japan","Cuba","Norway","Great Britain","Malaysia","Denmark","Ethiopia","Nigeria","United States","France","United States","France","France","France","Canada","Germany","Azerbaijan","Canada","Spain","Russia","Russia","Russia","Canada","Canada","Canada","Romania","Norway","Canada","United States","Australia","Denmark","Hungary","Italy","Romania","Georgia","Germany","Ukraine","Norway","Russia","Tunisia","United States","United States","United States","Germany","Netherlands-1","Canada","Bahamas","South Africa","Canada","Norway","Great Britain","Canada","Russia","Australia","Germany","Serbia","Cuba","Italy","Spain","Canada","China","New Zealand","Italy","United States","Serbia","Australia","Australia","Italy","United States","Canada","China","Great Britain","United States","Russia","Poland","France","Spain","United States","United States","Romania","Romania","France","Spain","Great Britain","Turkey","United States","Spain","Serbia","Azerbaijan","France","Canada","Brazil","Brazil","Serbia","Serbia","Great Britain","Nigeria","Canada","Canada","Canada","South Africa","France","Italy","Turkey","China","Italy","Italy","Germany","Belgium","Italy","Italy","Great Britain","Ethiopia","Ethiopia","Lithuania","Switzerland","United States","Germany","Russia","China","Mongolia","Czech Republic","Romania","Germany","China","China","Russia","United States","United States","Kazakhstan","Japan","Japan","Russia","Great Britain","United States","Estonia","Nigeria","Nigeria","Nigeria","China","Canada","Germany","China","Spain","Italy","Canada","Venezuela","Canada","Denmark","Italy","Australia","Norway","Austria","Sweden","Jamaica","Great Britain","China","Germany","Japan","Germany","Kazakhstan","Italy","United States","Belarus","China","Bahamas","Spain","Cote d'Ivoire","Ethiopia","South Africa","Germany","Belarus","Israel","Italy","Canada","United States","Russia","Spain","Great Britain","Kazakhstan","Canada","Germany","Germany","United States","Australia","Russia","Norway","Russia","France","South Korea","Germany","Japan","Japan","Germany","Japan","Japan","Germany","Denmark","Denmark","Denmark","United States","Germany","Germany","Germany","Germany","Czech Republic","Canada","Germany","Germany","Netherlands","Great Britain","Mexico","United States","Venezuela","Spain","Norway","Germany","United States","Great Britain","Great Britain","United States","Japan","South Africa","Czech Republic","Croatia","Azerbaijan","China","China","Uzbekistan","Egypt","Turkey","United States","Hungary","Japan","Japan","Japan","Japan","Russia","South Korea","Jamaica","Germany","United States","Estonia","Germany","South Korea-1","United States-2","Serbia","Greece","Bulgaria","Hungary","Russia","Russia","Bulgaria","Australia","Hungary","United States","Kazakhstan","Ukraine","Belarus","South Korea","South Korea","South Korea","North Korea","North Korea","South Korea","Canada","France","Japan","Poland","Russia","South Africa","South Africa","Russia","Japan","Greece ...
